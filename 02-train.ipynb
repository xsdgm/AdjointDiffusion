# %%
DATA_DIR = "/media/usb_media/datasets/physics/wg/64/class-cond"
LOG_DIR = "/media/usb_media/guided-diffusion-phy/wg-64_class-cond"
GPU_ID = 7

MODEL_FLAGS = "--dropout 0.1 --class_cond True --gray_imgs True"
DIFF_FLAGS = "--learn_sigma True --diffusion_steps 1000 --noise_schedule cosine"
DIR_FLAGS = f"--data_dir {DATA_DIR} --log_dir {LOG_DIR}"
TRAIN_FLAGS = f"--lr 1e-4 --batch_size 128 --microbatch 64 --gpu_id {GPU_ID}"

# !python3 image_train.py $MODEL_FLAGS $DIFF_FLAGS $DIR_FLAGS $TRAIN_FLAGS
